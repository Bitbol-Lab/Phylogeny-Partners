# %% [markdown]
# # Config

# %%
# %config IPCompleter.greedy=True 
import matplotlib
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import code_two_states.interface_graph as inter
import code_two_states.generation_sequences as ge 
import code_two_states.inference_partners as inf
import code_two_states.loop_function as lp
from code_two_states.utility_plot import *
import matplotlib.lines as mlines
import pickle
import seaborn as sns

########## ASPECT #################
width = "article"
width_pt = 430.00462

cmaps_sns = sns.color_palette("colorblind", 10)
l_AF = [0, 3, 2, 8, 1, 4, 5, 6, 7, 9]
cmaps = []
for i in l_AF:
    cmaps.append(cmaps_sns[i])
    
cmaps = np.array([(64, 83, 211), (221, 179, 16), (181, 29, 20), (0, 190, 255), (251, 73, 176), (0, 178, 93), (202, 202, 202)])/255 # http://tsitsul.in/blog/coloropt/
l = [1,0,5,2,4,3]
cmaps = cmaps[l]

sns.set_theme(context='notebook', style='ticks', palette=cmaps, color_codes=True, rc=None)

tex_fonts = {
    # Use LaTeX to write all text
    "text.usetex": False,
    "font.family": "arial",
    # Use 10pt font in plots, to maT_ch 10pt font in document
    "font.size": 9.8,
    "axes.titlesize" : 9.8,
    # Make the legend/label fonts a little smaller
    "legend.fontsize": 9,
    "axes.labelsize": 9,
    "xtick.labelsize": 9,
    "ytick.labelsize": 9,
    "lines.linewidth" : 1.3,
    'axes.linewidth' : 1,
    "figure.dpi" : 150
}

plt.rcParams.update(tex_fonts)
########## ASPECT #################

rng = np.random.default_rng()

### Dont touch this parameter #####
Size_Block = [100,100]
#p_in = 0.025
#p_out = 0.005
p_in = 0.02
p_out = 0.005


number_node_in_contact = 10
p_in_interface = 0.02
p_out_interface = 0.25

#################################
generate_graph = False ## Generate new graph with above parameter

###### INFERENCE #############
s_train = 400
pseudo_count = 0.5
pseudo_count_MI = 0.01
n_pair_species = 4
theta = 0
n_avg_permut_train_test = 20 # Number of different split in training and testing set for each MSA
n_avg_sampling = 20 ## Number of msa genereted for each couple of parameters
num_dot_x = 30

d_param = {
    "reg" : pseudo_count,
    "n_pair" : n_pair_species,
    "theta" : theta,
    "fast" : False,
    "s_train" : s_train,
    "n_mean" : n_avg_permut_train_test,
          }

d_param_MI = {
    "reg" : pseudo_count_MI,
    "n_pair" : n_pair_species,
    "theta" : theta,
    "fast" : False,
    "s_train" :s_train,
    "n_mean" : n_avg_permut_train_test,
            }

##############################

## Generation sequences ####
n_avg_sampling = 20
n_mutations_branch = 15
prob_mutation_site = n_mutations_branch/200
n_generations = 10 # 2^10 = 1024 chain of spin
n_seq = int(2**n_generations)
Tb = 3.0


label_0 = "Contacts only"
label_1 = "Phylo rand."
label_2 = "Contacts & phylogeny"
label_3 = "Phylogeny only"
label_4 = "Null model"
ylabel = "Correct prediction fraction"
ls_4 = "dotted"
ls_real_model = "--"

l_letter = ["A", "B", "C", "D", "E", "F", "G", "H", "I"]
def annotate(i, ax=None):
    if ax is None:
        plt.annotate(l_letter[i], xy=(-0.1, 1.1), xycoords='axes fraction')
    else:
        ax.annotate(l_letter[i], xy=(-0.1, 1.1), xycoords='axes fraction')
        
def annotate_all(ax):
    try:
        shape = ax.shape
    except:
        #no shape so no panels
        return None
    
    if len(ax.shape)==1:
        n = ax.shape[0]
        for i in range(n):
            annotate(i, ax=ax[i])
    elif len(ax.shape)==2:
        n,k = ax.shape
        for i in range(n):
            for j in range(k):
                annotate(i*n + j, ax=ax[i,j])

# %%
if generate_graph:
    Graph_SBM = nx.random_partition_graph(Size_Block, p_in, p_out)
    nx.write_gexf(Graph_SBM,"graphes/Graph_SBM")

    #p_in_2 = 0.025
    #p_out_2 = 0.02
    #Graph_SBM_2 = nx.random_partition_graph(Size_Block,p_in_2,p_out_2)
    
    Graph_Interface = inter.Interface_Graph(Size_Block, p_in_interface, p_out_interface, number_node_in_contact, seed=None)
    nx.write_gexf(Graph_Interface,"graphes/Graph_Interface")

m_adj = np.load("graphes/matcontact_andonis.npy")
Graph_erdos = nx.convert_matrix.from_numpy_matrix(m_adj)
Graph_erdos.name = "Erdős-Rényi"

Graph_SBM = nx.read_gexf("graphes/Graph_SBM",node_type = int)
Graph_SBM.name = "SBM"

Graph_Interface = nx.read_gexf("graphes/Graph_Interface",node_type = int)

Graph_HK_RR = nx.read_gexf("graphes/Extract_contact_pdb_HK-RR/Graph_HK_and_RR_Threshold_4",node_type = int)
Graph_HK_RR.name = "HK-RR"

### Liste Graph
L_Graph = [Graph_erdos, Graph_SBM, Graph_Interface, Graph_HK_RR]
###
Number_Graph = len(L_Graph)

figsize=set_size(width,subplots=(2,2))
plt.figure(figsize=figsize)  
for i in range(len(L_Graph)):
    node_color = []
    for node in range(len(L_Graph[i])):
        if L_Graph[i].nodes("subset")[node] == None:
            if node//Size_Block[0] == 0:
                L_Graph[i].nodes[node]["subset"] = 0
            else:
                L_Graph[i].nodes[node]["subset"] = 1
        if L_Graph[i].nodes[node]["subset"] == 0:
            node_color.append("forestgreen")
        else:
            node_color.append("darkmagenta")
    plt.subplot(2,Number_Graph//2 + Number_Graph%2 ,i+1)
    nx.draw_kamada_kawai(L_Graph[i],with_labels=False , node_size=10, node_color=node_color)
    annotate(i)
    plt.title(str(L_Graph[i].name))

#plt.savefig("figures_two_states/Graph_used.eps",bbox_inches = "tight")
plt.show()

# %% [markdown]
# ## Equilibrium for each graph

# %%
import time

ll_t = [[3,4.2,5], [1.5,2.1,3], [1.8,2.3,3], [5,7.1,9]]
L_max_flip = [10000]*(len(L_Graph)-1) + [20000]
n_seq = 1000

num_t = len(ll_t[0])
l_graph_temp = []
l_graph_flip = []
M_msa_hist = np.zeros((len(L_Graph),num_t,n_seq))
for i in range(len(L_Graph)):
    Graph = L_Graph[i]
    MSA = ge.Sampling_msa_two_states(Graph)
    max_flip = L_max_flip[i]
    delta_flip = int(max_flip/100)
    l_t_plot = []
    tot_time = 0
    l_t = ll_t[i]
    for i_t,t in enumerate(l_t):
        MSA.T = t
        msa = np.random.randint(2,size=(n_seq, Graph.number_of_nodes()), dtype = np.int8)*2-1
        l_plot = [np.mean(np.abs(np.mean(msa,axis=1)))]
        l_flip = [0]
        c = 0
        while c<max_flip:
            for j in range(msa.shape[0]):
                MSA.mcmc(delta_flip,msa[j])
            c+=delta_flip
            l_plot.append(np.mean(np.abs(np.mean(msa,axis=1))))
            l_flip.append(c)
        M_msa_hist[i,i_t] = np.mean(msa,axis=1)
        l_t_plot.append(l_plot)
    l_graph_flip.append(l_flip)
    l_graph_temp.append(l_t_plot)
# Out:
# Standard Temperature is 1.0
# Number of flip to reach equilibrium is 4000
# Standard Temperature is 1.0
# Number of flip to reach equilibrium is 4000
# Standard Temperature is 1.0
# Number of flip to reach equilibrium is 4000
# Standard Temperature is 1.0
# Number of flip to reach equilibrium is 4000

# %%
figsize=set_size(width,subplots=(2,2),scale_height=0.8)
plt.figure(figsize=figsize)
fig, ax =  plt.subplots(figsize=figsize, ncols=2, nrows=2)
for i_graph,graph in enumerate(L_Graph):
    l_t = ll_t[i_graph]
    for i,t in enumerate(l_t):
        l_t_plot =  l_graph_temp[i_graph]
        ax[i_graph//2,i_graph%2].plot(l_graph_flip[i_graph],l_t_plot[i],label="T=%s"%np.round(t,1))
        ax[i_graph//2,i_graph%2].margins(x=0)
        
        delta_annot = -19
        delta_pos = -0.17*(np.max(l_t_plot)-np.min(l_t_plot))
        ax[i_graph//2,i_graph%2].annotate("T=%s"%np.round(t,1), 
            xy=(l_graph_flip[i_graph][delta_annot], l_t_plot[i][delta_annot]), 
            xytext=(l_graph_flip[i_graph][delta_annot], l_t_plot[i][delta_annot] + delta_pos),
            color = cmaps[i])
        
        if i_graph==2:
            ax[i_graph//2,i_graph%2].set_xlabel("Number of accepted mutations")
            ax[i_graph//2,i_graph%2].set_ylabel("Absolute magnetization")
        if i_graph==0:
            ax[i_graph//2,i_graph%2].set_ylabel("Absolute magnetization")
        if i_graph==3:
            ax[i_graph//2,i_graph%2].set_xlabel("Number of accepted mutations")
    ax[i_graph//2,i_graph%2].set_title("%s: %s"%(l_letter[i_graph],str(L_Graph[i_graph].name)))

fig.tight_layout(pad=0.5)
fig.savefig("figures_two_states/S2_magnetisation_graph.eps")

# %%
figsize=set_size(width,subplots=(len(L_Graph),len(l_t)),fraction=1)
plt.figure(figsize=figsize)
for i in range(len(L_Graph)):
    Graph = L_Graph[i]
    l_t = ll_t[i]
    for i_t,t in enumerate(l_t):
        plt.subplot(len(L_Graph),len(l_t),(i_t+1) + (i)*len(l_t))
        if i+1==len(L_Graph):
            plt.xlabel("Magnetization")
        if i_t == 0:
            if "-" in str(Graph):
                name_graph = "$\\bf{%s}$"%(str(Graph)[:str(Graph).index("-")]) + "-$\\bf{%s}$"%(str(Graph.name)[str(Graph.name).index("-")+1:])
            else:
                name_graph = "$\\bf{%s}$"%(Graph)
            plt.ylabel("%s \nCounts"%(name_graph))
        plt.title("T = %s"%(np.round(t*100)/100))
        bins = np.arange(-1,1,16/Graph.number_of_nodes())
        plt.hist(M_msa_hist[i,i_t],bins=bins,range=(-1,1), color=cmaps[1])
plt.tight_layout(pad=0.1)
plt.savefig("figures_two_states/S3_histo_magnetisation.eps", bbox_inches="tight")

# %% [markdown]
# ## Global parameter

# %%
l_tc = [3.8 , 2.7 , 2.4 , 7] ## List of the critical temperature
## Temperature ####
LL_T = [np.linspace(0.5*tc,2.5*tc, num = 20) for tc in l_tc]

# %% [markdown]
# ## Generation of Sequence

# %%
l_graph_temp_no_phylo, l_graph_temp_phylo_equi, l_graph_msa_pure_phylo = [], [], []

for ind_Graph, Graph in enumerate(L_Graph):
    print("Graph : " + str(ind_Graph) )
    sampling = ge.Sampling_msa_two_states(Graph, flip_equi=L_max_flip[ind_Graph]) 

    l_temp = LL_T[ind_Graph]
    n_mutations_branch_graph = int(prob_mutation_site*L_Graph[ind_Graph].number_of_nodes())
    print("%s : %s mutations per generation"%(str(ind_Graph),n_mutations_branch_graph))

    l_graph_temp_no_phylo.append(lp.loop_sampling_temperature(n_avg_sampling, l_temp, sampling, sampling.msa_no_phylo, n_seq))
    l_graph_temp_phylo_equi.append(lp.loop_sampling_temperature(n_avg_sampling, l_temp, sampling, sampling.msa_binary_tree,
                                                             n_generations, n_mutations_branch_graph, 1))

    l_graph_msa_pure_phylo.append(lp.loop_on_function(n_avg_sampling, sampling.msa_binary_tree_pure_phylo,
                                                      n_generations, n_mutations_branch_graph, 0))
# Out:
# Graph : 0
# Standard Temperature is 1.0
# Number of flip to reach equilibrium is 10000
# 0 : 15 mutations per generation
# Graph : 1
# Standard Temperature is 1.0
# Number of flip to reach equilibrium is 10000
# 1 : 15 mutations per generation
# Graph : 2
# Standard Temperature is 1.0
# Number of flip to reach equilibrium is 10000
# 2 : 15 mutations per generation
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [7], in <module>
#       8 n_mutations_branch_graph = int(prob_mutation_site*L_Graph[ind_Graph].number_of_nodes())
#       9 print("%s : %s mutations per generation"%(str(ind_Graph),n_mutations_branch_graph))
# ---> 11 l_graph_temp_no_phylo.append(lp.loop_sampling_temperature(n_avg_sampling, l_temp, sampling, sampling.msa_no_phylo, n_seq))
#      12 l_graph_temp_phylo_equi.append(lp.loop_sampling_temperature(n_avg_sampling, l_temp, sampling, sampling.msa_binary_tree,
#      13                                                          n_generations, n_mutations_branch_graph, 1))
#      15 l_graph_msa_pure_phylo.append(lp.loop_on_function(n_avg_sampling, sampling.msa_binary_tree_pure_phylo,
#      16                                                   n_generations, n_mutations_branch_graph, 0))
#
# File ~/ARPE/git_repo/Phylogeny-Partners-final/2_states/code_two_states/loop_function.py:80, in loop_sampling_temperature(n_avg, l_temp, sampling, func, *args)
#      78 for T in l_temp:
#      79     sampling.T = T
# ---> 80     l.append(loop_on_function(n_avg,func,*args))
#      81 return l
#
# File ~/ARPE/git_repo/Phylogeny-Partners-final/2_states/code_two_states/loop_function.py:24, in loop_on_function(n_iter, function, *args)
#      22 l = []
#      23 for i in range(n_iter):
# ---> 24     l.append(function(*args))
#      25 return np.array(l)
#
# File generation_sequences.pyx:57, in generation_sequences.Sampling_msa_two_states.msa_no_phylo()
#
# File /usr/local/lib/python3.8/dist-packages/numpy/core/_asarray.py:23, in asarray(a, dtype, order, like)
#      19 def _asarray_dispatcher(a, dtype=None, order=None, *, like=None):
#      20     return (like,)
# ---> 23 @set_array_function_like_doc
#      24 @set_module('numpy')
#      25 def asarray(a, dtype=None, order=None, *, like=None):
#      26     """Convert the input to an array.
#      27
#      28     Parameters
#    (...)
#      97
#      98     """
#      99     if like is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Impact of the temperature on several graph

# %%
l_middle_index = [np.argwhere(np.diff([G.nodes[node]["subset"] for node in range(G.number_of_nodes())])==True)[0,0]+1 for G in L_Graph]

kwargs = {"s_train" : s_train,
         "reg": pseudo_count,
          "n_pair" : n_pair_species,
          "theta" : theta,
          "fast" : True,
          "l_middle_index" : l_middle_index,
            "n_mean" : n_avg_permut_train_test,
         }

print(kwargs)
l_no_phylo_temp = lp.loop_inf_partners_diff_graph(inf.Inference_Partner, l_graph_temp_no_phylo,**kwargs)
l_binary_tree_equi_temp = lp.loop_inf_partners_diff_graph(inf.Inference_Partner,l_graph_temp_phylo_equi,**kwargs)

tree_rand_phylo = []
for l_msa_pure_phylo in l_graph_msa_pure_phylo:
    tree_rand_phylo.append(inf.Inference_Partner(l_msa_pure_phylo, s_train, pseudo_count, n_pair_species, theta=theta, fast=True, middle_index=None))

# %%
label_0 = "Contacts only"
label_2 = "Contacts & phylogeny"
label_3 = "Phylogeny only"
label_4 = "Null model"
ylabel = "Correct prediction fraction"

figsize=set_size(width,subplots=(2,2),scale_height=1)
fig, ax =  plt.subplots(figsize=figsize, ncols=2, nrows=2)
for i in range(len(LL_T)):
    ax[i//2,i%2].plot(LL_T[i],l_binary_tree_equi_temp[i], label=label_2, color=cmaps[1])
    ax[i//2,i%2].plot(LL_T[i],l_no_phylo_temp[i], label=label_0, color=cmaps[0])
    ax[i//2,i%2].plot(LL_T[i],[tree_rand_phylo[i] for t in LL_T[i]], label=label_3, color=cmaps[2])
    ax[i//2,i%2].plot(LL_T[i],[1/n_pair_species for t in LL_T[i]] , label=label_4, color=cmaps[3], ls="dotted")
    ax[i//2,i%2].set_title(l_letter[i] + ": " + str(L_Graph[i]))
    ax[i//2,i%2].set_ylim(0.2,1)
    ax[i//2,i%2].margins(x=0)

ax[1,0].set_xlabel("Temperature")
ax[1,1].set_xlabel("Temperature")
ax[0,0].set_ylabel("Correct prediction fraction")
ax[1,0].set_ylabel("Correct prediction fraction")
#ax.semilogx()
#ax[0,0].grid(which='both')
#ax[1,0].grid(which='both')
#ax[0,1].grid(which='both')
#ax[1,1].grid(which='both')

fig.tight_layout(h_pad=0.1)

ax[0,0].legend(bbox_to_anchor=(2.3,1.5),loc='best', ncol=4)


fig.savefig("figures_two_states/S6_Partners_temperature_different_graph.eps",bbox_inches = "tight")
plt.show()

# %% [markdown]
# ## Impact from Sampling on different graph

# %%
l_n_mutations_branch = np.linspace(2, 100, num=num_dot_x, dtype=int)
d_muta = {"n_mutations_branch" : l_n_mutations_branch}

graph_l_l_msa_binary_tree_rand_phylo, graph__l_msa_no_phylo_Tb, graph_l_l_msa_binary_tree_equi_Tb = [], [], []

for ind_Graph, Graph in enumerate(L_Graph):
    print("Graph : " + str(ind_Graph))
    sampling = ge.Sampling_msa_two_states(Graph)
    sampling.T = Tb
    graph_l_l_msa_binary_tree_rand_phylo.append(lp.loop_sampling_parameter(n_avg_sampling, d_muta, sampling.msa_binary_tree_pure_phylo, n_generations=n_generations, start_equi=0))
    graph_l_msa_no_phylo_Tb.append(lp.loop_on_function(n_avg_sampling, sampling.msa_no_phylo, n_seq))
    graph_l_l_msa_binary_tree_equi_Tb.append(lp.loop_sampling_parameter(n_avg_sampling, d_muta, sampling.msa_binary_tree, n_generations=n_generations, start_equi=1))

# %%
graph_l_binary_tree_rand_phylo_nmu, graph_no_phylo_Tb_nmu, graph_l_binary_tree_equi_mut_Tb_nmu = [], [], []
for i, Graph in enumerate(L_Graph):
    print("Graph : " + str(i))
    graph_l_binary_tree_rand_phylo_nmu.append(lp.loop_inf_partners_data(inf.Inference_Partner, graph_l_l_msa_binary_tree_rand_phylo[i], **d_param))
    graph_no_phylo_Tb_nmu.append(inf.Inference_Partner(graph_l_msa_no_phylo_Tb[i], **d_param))
    graph_l_binary_tree_equi_mut_Tb_nmu.append(lp.loop_inf_partners_data(inf.Inference_Partner, graph_l_l_msa_binary_tree_equi_Tb[i], **d_param))

## MI ##
#l_binary_tree_rand_phylo_MI_nmu = lp.loop_inf_partners_data(mu.Inference_Partner_Mutual_Info, l_l_msa_binary_tree_rand_phylo, **d_param_MI)
#no_phylo_Tb_MI_nmu = mu.Inference_Partner_Mutual_Info(l_msa_no_phylo_Tb, **d_param_MI)
#l_binary_tree_equi_mut_Tb_MI_nmu = lp.loop_inf_partners_data(mu.Inference_Partner_Mutual_Info, l_l_msa_binary_tree_equi_Tb, **d_param_MI)

# %%
import matplotlib.lines as mlines
label_0 = "Contacts only"
label_1 = "Phylo rand."
label_2 = "Contacts & phylogeny"
label_3 = "Phylogeny only"
label_4 = "Null model"
ylabel = "Correct prediction fraction"
ls_4 = "dotted"
ls_real_model = "--"

figsize=set_size(width,subplots=(2,2),scale_height=1)
fig, ax =  plt.subplots(figsize=figsize, ncols=2, nrows=2)
for i in range(len(L_Graph)):
    ax[i//2,i%2].plot(l_n_mutations_branch, graph_l_binary_tree_equi_mut_Tb_nmu[i], label=label_2, color=cmaps[1])
    ax[i//2,i%2].plot(l_n_mutations_branch, [graph_no_phylo_Tb_nmu[i] for j in range(len(l_n_mutations_branch))], label=label_0, color=cmaps[0])
    ax[i//2,i%2].plot(l_n_mutations_branch, graph_l_binary_tree_rand_phylo_nmu[i], label=label_3, color=cmaps[2])
    ax[i//2,i%2].hlines(1/n_pair_species,l_n_mutations_branch[0],l_n_mutations_branch[-1], color=cmaps[3], label=label_4, ls=ls_4)
    ax[i//2,i%2].set_title(l_letter[i] + ": " + str(L_Graph[i]))
    ax[i//2,i%2].set_ylim(0.2,1)
    ax[i//2,i%2].margins(x=0)
    ax[i//2,i%2].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())

ax[1,0].set_xlabel("Number of mutations per branch")
ax[1,1].set_xlabel("Number of mutations per branch")
ax[0,0].set_ylabel("Correct prediction fraction")
ax[1,0].set_ylabel("Correct prediction fraction")
#ax.semilogx()
#ax[0,0].grid(which='both')
#ax[1,0].grid(which='both')
#ax[0,1].grid(which='both')
#ax[1,1].grid(which='both')

fig.tight_layout(h_pad=0.1)

ax[0,0].legend(bbox_to_anchor=(2.3,1.5),loc='best', ncol=4)


fig.savefig("figures_two_states/2_Partners_NumberMutation_different_graph.eps",bbox_inches = "tight")
plt.show()


##MI##
#ax.plot(l_n_mutations_branch,[no_phylo_Tb_MI_nmu for i in l_n_mutations_branch], label = label_0, color=cmaps[0], ls="--")
#ax.plot(l_n_mutations_branch, l_binary_tree_equi_mut_Tb_MI_nmu, label = label_2, color=cmaps[1], ls="--")
#ax.plot(l_n_mutations_branch, l_binary_tree_rand_phylo_MI_nmu, label = label_3, color=cmaps[2], ls="--")


#fig.tight_layout()
#fig.savefig("figures_two_states/Partners_NumberMutation_lw=_%s_%s_%s_ls=_%s.eps"%(lw_2,lw_0,lw_3,ls_4),bbox_inches = "tight")
plt.show()

# %% [markdown]
# ## Figure 2 on Interface graph

# %%
import importlib
importlib.reload(ge)
l_n_mutations_branch = np.linspace(2, 100, num=num_dot_x, dtype=int)
d_muta = {"n_mutations_branch" : l_n_mutations_branch}
sampling = ge.Sampling_msa_two_states(Graph_Interface, flip_equi=10000, T=float(4.0))

#l_l_msa_binary_tree_rand_phylo = lp.loop_sampling_parameter(n_avg_sampling, d_muta, sampling.msa_binary_tree_pure_phylo, n_generations=n_generations, start_equi=0)
#l_msa_no_phylo_Tb = lp.loop_on_function(n_avg_sampling, sampling.msa_no_phylo, n_seq)
l_l_msa_binary_tree_equi_Tb = lp.loop_sampling_parameter(n_avg_sampling, d_muta, sampling.msa_binary_tree, n_generations=n_generations, start_equi=1)
# Out:
# Standard Temperature is 4.0
# Number of flip to reach equilibrium is 10000

# %%
l_binary_tree_equi_mut_Tb_nmu = lp.loop_inf_partners_data(inf.Inference_Partner, l_l_msa_binary_tree_equi_Tb, **d_param)
l_binary_tree_equi_mut_Tb_nmu_true_coupling = lp.loop_inf_partners_data(inf.Inference_Partner, l_l_msa_binary_tree_equi_Tb, graph=Graph_Interface, **d_param)
l_binary_tree_equi_mut_Tb_nmu_false_contact = lp.loop_inf_partners_data(inf.Inference_Partner, l_l_msa_binary_tree_equi_Tb, graph=Graph_Interface, false_contact=True, **d_param)
l_binary_tree_equi_mut_Tb_nmu_single_contact = lp.loop_inf_partners_data(inf.Inference_Partner, l_l_msa_binary_tree_equi_Tb, graph=Graph_Interface, single_site_contact=True, **d_param)
l_binary_tree_equi_mut_Tb_nmu_single_false_contact = lp.loop_inf_partners_data(inf.Inference_Partner, l_l_msa_binary_tree_equi_Tb, graph=Graph_Interface, single_false_contact=True, **d_param)
# Out:
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [15], in <module>
#       3 l_binary_tree_equi_mut_Tb_nmu = lp.loop_inf_partners_data(inf.Inference_Partner, l_l_msa_binary_tree_equi_Tb, **d_param)
#       4 l_binary_tree_equi_mut_Tb_nmu_true_coupling = lp.loop_inf_partners_data(inf.Inference_Partner, l_l_msa_binary_tree_equi_Tb, graph=Graph_Interface, **d_param)
# ----> 5 l_binary_tree_equi_mut_Tb_nmu_false_contact = lp.loop_inf_partners_data(inf.Inference_Partner, l_l_msa_binary_tree_equi_Tb, graph=Graph_Interface, false_contact=True, **d_param)
#       6 l_binary_tree_equi_mut_Tb_nmu_single_contact = lp.loop_inf_partners_data(inf.Inference_Partner, l_l_msa_binary_tree_equi_Tb, graph=Graph_Interface, single_site_contact=True, **d_param)
#       7 l_binary_tree_equi_mut_Tb_nmu_single_false_contact = lp.loop_inf_partners_data(inf.Inference_Partner, l_l_msa_binary_tree_equi_Tb, graph=Graph_Interface, single_false_contact=True, **d_param)
#
# File ~/ARPE/git_repo/Phylogeny-Partners-final/2_states/code_two_states/loop_function.py:73, in loop_inf_partners_data(func, data, *args, **kwargs)
#      71 l=[]
#      72 for x in data:
# ---> 73     l.append(func(x, *args, **kwargs))
#      74 return np.array(l)
#
# File ~/ARPE/git_repo/Phylogeny-Partners-final/2_states/code_two_states/inference_partners.py:50, in Inference_Partner(l_msa, s_train, reg, n_pair, theta, fast, middle_index, n_mean, graph, Jij_para, false_contact, msa_testing_input, msa_train_input, single_site_contact, single_false_contact, **kwargs)
#      48 if false_contact:
#      49     Jij = false_contact_Jij(Jij, graph)
# ---> 50 elif single_site_contact:
#      51     Jij = single_contact_Jij(Jij, graph)
#      52 elif single_false_contact:
#
# File ~/ARPE/git_repo/Phylogeny-Partners-final/2_states/code_two_states/inference_partners.py:139, in false_contact_Jij(Jij, graph)
#     137     for j in range(i+1, Jij.shape[1]):
#     138         if (i,j) in t_edge:
# --> 139             Jij_return[i,j]=0
#     140             Jij_return[j,i]=0
#     141 return Jij_return
#
# File ~/.local/lib/python3.8/site-packages/networkx/classes/reportviews.py:1144, in EdgeView.__contains__(self, e)
#    1142 try:
#    1143     u, v = e[:2]
# -> 1144     return v in self._adjdict[u] or u in self._adjdict[v]
#    1145 except (KeyError, ValueError):
#    1146     return False
#
# KeyboardInterrupt:

# %%
import code_two_states.utility_plot as ut_plot
figsize = ut_plot.set_size(width_pt/2,subplots=(1,1))
fig, ax =  plt.subplots(figsize=figsize, ncols=1)

ax.plot(l_n_mutations_branch, l_binary_tree_equi_mut_Tb_nmu)
ax.plot(l_n_mutations_branch, l_binary_tree_equi_mut_Tb_nmu_true_coupling)
ax.plot(l_n_mutations_branch, l_binary_tree_equi_mut_Tb_nmu_false_contact)
#ax.plot(l_n_mutations_branch, l_binary_tree_equi_mut_Tb_nmu_true_model, ls=ls_real_model, color=cmaps[4])
ax.plot(l_n_mutations_branch, l_binary_tree_equi_mut_Tb_nmu_single_contact, color=cmaps[5])
ax.plot(l_n_mutations_branch, l_binary_tree_equi_mut_Tb_nmu_single_false_contact, color=cmaps[4])

ax.hlines(1/n_pair_species,l_n_mutations_branch[0],l_n_mutations_branch[-1], color=cmaps[3], ls=ls_4)
ax.get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
#ax.legend(bbox_to_anchor=(1, 1.15))
ax.set_ylim(0.2,1)

ax.set_ylabel(ylabel)
ax.set_xlabel("Number of mutations per branch")
annotate_all(ax)

Lhandles = []
#Lhandles.append(mlines.Line2D([],[],ls = '-', color = "black", label = "mfDCA"))
Lhandles.append( mlines.Line2D([], [], color=cmaps[0], markersize=15, label="Complete score"))
Lhandles.append( mlines.Line2D([], [], color=cmaps[1], label="Score restricted to contacts"))
Lhandles.append( mlines.Line2D([], [], color=cmaps[2], label="Score restricted to non-contacts"))
Lhandles.append( mlines.Line2D([], [], color=cmaps[5], label="Score restricted to single sites (30)"))
Lhandles.append( mlines.Line2D([], [], color=cmaps[4], markersize=15, label="Score restricted to 30 random sites,\nexcluding contacts"))
Lhandles.append( mlines.Line2D([], [], color=cmaps[3], markersize=15, label=label_4, ls=ls_4))
ax.legend(bbox_to_anchor=(1, 1), handles=Lhandles, markerfirst=True)

#fig.tight_layout()
fig.savefig("figures_two_states/4_Partners_NumberMutation_true_contacts_Interface.eps",bbox_inches = "tight")
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
